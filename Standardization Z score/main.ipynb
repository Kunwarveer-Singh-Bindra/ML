# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df = df.iloc[:,2:]

# %%
df.sample(5)
# Out:
#      Age  EstimatedSalary  Purchased
# 35    35            27000          0
# 80    30            80000          0
# 300   58            38000          1
# 48    30           135000          1
# 267   37            74000          0

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.iloc[:,:2], df.iloc[:,2:3], test_size = 0.3, random_state = 0)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((280, 2), (120, 2), (280, 1), (120, 1))

# %%
x_train.head()
# Out:
#      Age  EstimatedSalary
# 92    26            15000
# 223   60           102000
# 234   38           112000
# 232   40           107000
# 377   42            53000

# %%
y_train.head()
# Out:
#      Purchased
# 92           0
# 223          1
# 234          0
# 232          1
# 377          0

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train_scaled = sc.fit_transform(x_train)
x_test_scaled = sc.transform(x_test)

# %%
sc.mean_
# Out:
# array([3.78642857e+01, 6.98071429e+04])

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns = x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled, columns = x_test.columns)

# %%
x_train_scaled.sample(5)
# Out:
#           Age  EstimatedSalary
# 171 -0.280814        -0.486047
# 48  -0.672973         1.393691
# 24  -0.280814         0.063415
# 79  -0.280814         0.612877
# 142  0.993704        -1.180104

# %%
x_test_scaled.sample(5)
# Out:
#          Age  EstimatedSalary
# 35 -1.947491        -0.514966
# 44  0.503504         1.220177
# 84  1.974102        -0.919832
# 90  0.405465        -0.167937
# 77  0.209385        -0.283613

# %%
np.round(x_train_scaled.describe(), 1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.8             -0.8
# 50%     -0.1              0.0
# 75%      0.8              0.5
# max      2.2              2.3

# %%
np.round(x_train.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.9          69807.1
# std     10.2          34641.2
# min     18.0          15000.0
# 25%     30.0          43000.0
# 50%     37.0          70500.0
# 75%     46.0          88000.0
# max     60.0         150000.0

# %%
sns.scatterplot(x = x_train_scaled['Age'], y = x_train_scaled['EstimatedSalary'])
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
sns.scatterplot(x = df['Age'], y = df['EstimatedSalary'])
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>
