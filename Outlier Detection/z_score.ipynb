# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\kunwa\PycharmProjects\ML\Outlier Detection\placement.csv")

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
sns.displot(df["cgpa"], kde = True)
sns.displot(df["placement_exam_marks"], kde = True)

# %%
mean_cgpa = df["cgpa"].mean()
std_cgpa = df["cgpa"].std()
min_cgpa = df["cgpa"].min()
max_cgpa = df["cgpa"].max()
print(mean_cgpa)
print(std_cgpa)
print(min_cgpa)
print(max_cgpa)
# Out:
# 6.96124
# 0.6158978751323896
# 4.89
# 9.12

# %%
print(f"heighest allowed {mean_cgpa + (3 * std_cgpa)}")
print(f"Lowest allowed {mean_cgpa - (3*std_cgpa)}")
# Out:
# heighest allowed 8.808933625397168
# Lowest allowed 5.113546374602832

# %%
df[(df['cgpa'] > 8.808933625397168) | (df['cgpa'] < 5.113546374602832)]
# Out:
#      cgpa  placement_exam_marks  placed
# 485  4.92                  44.0       1
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 999  4.90                  10.0       1
