# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\kunwa\PycharmProjects\ML\Outlier Detection\placement.csv")
df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
sns.displot(df["cgpa"], kde = True)
sns.displot(df["placement_exam_marks"], kde = True)

# %%
df["placement_exam_marks"].describe()
# Out:
# count    1000.000000
# mean       32.225000
# std        19.130822
# min         0.000000
# 25%        17.000000
# 50%        28.000000
# 75%        44.000000
# max       100.000000
# Name: placement_exam_marks, dtype: float64

# %%
sns.boxplot(data = df["placement_exam_marks"])
# Out:
# <Axes: ylabel='placement_exam_marks'>

# %%
percentile_25 = df["placement_exam_marks"].quantile(0.25)
percentile_75 = df["placement_exam_marks"].quantile(0.75)
iqr = percentile_75 - percentile_25

# %%
upper_limit = percentile_75 + (1.5*iqr)
lower_limit = percentile_25 - (1.5*iqr)

# %%
new_df = df[(df["placement_exam_marks"] > lower_limit) & (df["placement_exam_marks"] < upper_limit)]

# %%
new_df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [985 rows x 3 columns]

# %%
sns.displot(new_df["cgpa"], kde = True)

# %%
mean_cgpa = df["cgpa"].mean()
std_cgpa = df["cgpa"].std()

# %%
upper_std_limit = mean_cgpa + (3 * std_cgpa)
lower_std_limit = mean_cgpa - (3 * std_cgpa)

# %%
latest_df = new_df[(df["cgpa"] >  lower_limit) & (df["cgpa"] < upper_limit)]
latest_df
# Out:
# C:\Users\kunwa\AppData\Local\Temp\ipykernel_21900\1359644801.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   latest_df = new_df[(df["cgpa"] >  lower_limit) & (df["cgpa"] < upper_limit)]
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [985 rows x 3 columns]

# %%
sns.boxplot(data = new_df["placement_exam_marks"])
# Out:
# <Axes: ylabel='placement_exam_marks'>

# %%
sns.boxplot(data = latest_df["cgpa"])
# Out:
# <Axes: ylabel='cgpa'>

# %%
quantile_25 = new_df["cgpa"].quantile(.25)
quantile_75 = new_df["cgpa"].quantile(.75)
iqr_cgpa = quantile_75 - quantile_25
upper_limit = quantile_75 + (1.5* iqr_cgpa)
lower_limit = quantile_25 - (1.5* iqr_cgpa)

# %%
new_df = latest_df[(latest_df["cgpa"] < upper_limit) & (latest_df["cgpa"] > lower_limit)]
new_df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 990  6.17                  33.0       1
# 991  7.04                  57.0       0
# 992  6.26                  12.0       0
# 993  6.73                  21.0       1
# 994  6.48                  63.0       0
#
# [977 rows x 3 columns]

# %%
sns.displot(new_df["cgpa"], kde = True)

# %%
sns.displot(new_df["placement_exam_marks"], kde = True)

# %%
sns.boxplot(new_df["cgpa"])
# Out:
# <Axes: ylabel='cgpa'>

# %%
sns.boxplot(new_df["placement_exam_marks"])
# Out:
# <Axes: ylabel='placement_exam_marks'>
