# %%
import numpy as np

# %%
a = np.array([[[1,2,3],[1,2,3]],[[1,2,3],[4,5,6]],[[1,2,3],[7,8,9]]])

# %%
a.ndim
# Out:
# 3

# %%
 a
# Out:
# array([[[1, 2, 3],
#         [1, 2, 3]],
#
#        [[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [7, 8, 9]]])

# %%
a.shape
# Out:
# (3, 2, 3)

# %%
a.size
# Out:
# 18
